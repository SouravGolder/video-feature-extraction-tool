# %%
pip install opencv-python numpy pytesseract notebook ipykernel
# Out:
# Requirement already satisfied: opencv-python in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (4.13.0.90)
# Requirement already satisfied: numpy in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (2.4.1)
# Requirement already satisfied: pytesseract in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.3.13)
# Requirement already satisfied: notebook in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (7.5.3)
# Requirement already satisfied: ipykernel in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (7.1.0)
# Requirement already satisfied: packaging>=21.3 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pytesseract) (26.0)
# Requirement already satisfied: Pillow>=8.0.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pytesseract) (12.1.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from notebook) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from notebook) (2.28.0)
# Requirement already satisfied: jupyterlab<4.6,>=4.5.3 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from notebook) (4.5.3)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from notebook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from notebook) (6.5.4)
# Requirement already satisfied: anyio>=3.1.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.12.1)
# Requirement already satisfied: argon2-cffi>=21.1 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.17.0)
# Requirement already satisfied: nbformat>=5.3.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.24.1)
# Requirement already satisfied: pywinpty>=2.0.1 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.0.2)
# Requirement already satisfied: pyzmq>=24 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyterlab<4.6,>=4.5.3->notebook) (2.1.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyterlab<4.6,>=4.5.3->notebook) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyterlab<4.6,>=4.5.3->notebook) (2.3.0)
# Requirement already satisfied: setuptools>=41.1.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyterlab<4.6,>=4.5.3->notebook) (80.10.2)
# Requirement already satisfied: certifi in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.3->notebook) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.3->notebook) (1.0.9)
# Requirement already satisfied: idna in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.3->notebook) (3.11)
# Requirement already satisfied: h11>=0.16 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.3->notebook) (0.16.0)
# Requirement already satisfied: babel>=2.10 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (4.26.0)
# Requirement already satisfied: requests>=2.31 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (2.32.5)
# Requirement already satisfied: comm>=0.1.1 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipykernel) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipykernel) (9.9.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: argon2-cffi-bindings in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: colorama>=0.4.4 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.5.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.30.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.5.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (6.0.3)
# Requirement already satisfied: rfc3339-validator in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: fqdn in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.1.0)
# Requirement already satisfied: uri-template in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (6.3.0)
# Requirement already satisfied: defusedxml in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: webencodings in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.21.2)
# Requirement already satisfied: six>=1.5 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook) (2.6.3)
# Requirement already satisfied: lark>=1.2.2 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# Requirement already satisfied: cffi>=2.0.0b1 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.0.0)
# Requirement already satisfied: pycparser in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from cffi>=2.0.0b1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.15.0)
# Requirement already satisfied: arrow>=0.15.0 in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.4.0)
# Requirement already satisfied: tzdata in .\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (2025.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
import json
import os


def detect_shot_cuts(video_path, threshold=0.3):
    cap = cv2.VideoCapture(video_path)
    prev_hist = None
    cut_count = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        hist = cv2.calcHist([gray], [0], None, [256], [0, 256])
        hist = cv2.normalize(hist, hist).flatten()

        if prev_hist is not None:
            diff = cv2.compareHist(prev_hist, hist, cv2.HISTCMP_BHATTACHARYYA)
            if diff > threshold:
                cut_count += 1

        prev_hist = hist

    cap.release()
    return cut_count


def compute_average_motion(video_path):
    cap = cv2.VideoCapture(video_path)
    ret, prev_frame = cap.read()
    if not ret:
        return 0.0

    prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)
    motion_values = []

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        flow = cv2.calcOpticalFlowFarneback(
            prev_gray, gray, None,
            pyr_scale=0.5,
            levels=3,
            winsize=15,
            iterations=3,
            poly_n=5,
            poly_sigma=1.2,
            flags=0
        )

        magnitude, _ = cv2.cartToPolar(flow[..., 0], flow[..., 1])
        motion_values.append(np.mean(magnitude))
        prev_gray = gray

    cap.release()
    return float(np.mean(motion_values)) if motion_values else 0.0


def compute_text_presence_ratio(video_path, frame_interval=30):
    cap = cv2.VideoCapture(video_path)
    total_frames = 0
    text_frames = 0
    frame_count = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        frame_count += 1
        if frame_count % frame_interval != 0:
            continue

        total_frames += 1
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        text = pytesseract.image_to_string(gray)

        if len(text.strip()) > 5:
            text_frames += 1

    cap.release()
    if total_frames == 0:
        return 0.0
    return text_frames / total_frames


def extract_video_features(video_path):
    if not os.path.exists(video_path):
        raise FileNotFoundError("Video file not found")

    features = {
        "video_path": video_path,
        "shot_cut_count": detect_shot_cuts(video_path),
        "average_motion": compute_average_motion(video_path),
        "text_present_ratio": compute_text_presence_ratio(video_path)
    }

    return features


if __name__ == "__main__":
    video_path = "sample_video.mp4"  # Video sample path
    features = extract_video_features(video_path)

    print(json.dumps(features, indent=4))
# Out:
# {
#     "video_path": "sample_video (2).mp4",
#     "shot_cut_count": 0,
#     "average_motion": 1.6426894664764404,
#     "text_present_ratio": 0.5714285714285714
# }
